# %%
import pandas as pd
import requests
import re

# %%
def country_or_nationality(df: "country vs nationality dataframe",
                           mode: "c for country, n for nationality, b for both"):
    """
    :param df: country vs nationality dataframe
    :param mode: c for country, n for nationality, b for both
    :return: returns a list containing countries or nationalities
    """
    cn = df.values.tolist()
    coun, nati = zip(*cn)
    if mode == "c":
        return coun
    elif mode == "n":
        return nati
    elif mode == "b":
        return cn
    else:
        return None


def null_values(df, mode: "g, c or a", tolist=False):
    """
    :param df: Clean dataframe
    :param mode: g for gender, c for country and a for age
    :param tolist: creates a list of names from the dataframe
    :return: 1. returns a pandas dataframe with empty gender or country registries,
            depending on mode selection. If tolist is set to True, it will return a list of names
    """
    if mode == "g":
        # Creating dataframe with empty values
        nullgender = df[df["gender"].isnull()].iloc[:, :2]  # 550

        # Creating search name column. This column will be used to access each's millionaire wikipedia page.
        nullgender["SearchName"] = nullgender["name"].apply(lambda full_name: "_".join(full_name.strip().split()))

        if tolist:
            return nullgender["SearchName"].values.tolist()
        else:
            return nullgender

    elif mode == "c":
        # Creating dataframe with empty values
        nullcountry = df[df["country"].isnull()].iloc[:, :2]  # 1391

        # Creating search name column. This column will be used to access each's millionaire wikipedia page.
        nullcountry["SearchName"] = nullcountry["name"].apply(lambda full_name: "_".join(full_name.strip().split()))
        if tolist:
            return nullcountry["SearchName"].values.tolist()
        else:
            return nullcountry

    elif mode == "a":
        # Creating dataframe with empty values
        nullage = df[df["age"].isnull()].iloc[:, :2]  # 1391

        # Creating search name column. This column will be used to access each's millionaire wikipedia page.
        nullage["SearchName"] = nullage["name"].apply(lambda full_name: "_".join(full_name.strip().split()))
        if tolist:
            return nullage["SearchName"].values.tolist()
        else:
            return nullage
    else:
        return None


def search_list(df: "dataframe to parse"):
    return df["SearchName"].values.tolist()


def get_age(nums: "List of 19xx years"):
    if len(nums) == 1:
        return 2019 - int(nums[0])
    else:
        return None


def country_search(words: "list of words in Born tag", countries: "list of countries in countries tuple"):
    for word in words:
        for country in countries:
            if word == country:
                return country
    else:
        return None


def nationality_country(Natio: "Nationality to search", CvsN: "Country vs. Nationality relationship table"):
    for element in CvsN:
        if element[1] == Natio:
            return element[0]
    else:
        return None

# %%
def data_enhancement(millionaires, enh_mode, con):
    """
    :param millionaires: List of millionaires to parse
    :param enh_mode: enhancement mode, c for country, a for age
    :param con: Country vs Nationality dataframe
    :return:
    """

    counter = 0
    mill_lst = []
    for millionaire in millionaires:
        url = f"https://en.wikipedia.org/wiki/{millionaire}"

        # Checking whether the page exists.
        if str(requests.get(url)) == "<Response [404]>":
            mill_lst.append((millionaire, None))
            counter += 1
            print(counter, millionaire, "<Response [404]>")
            continue

        # Checking if there are tables in the page.
        try:
            pd.read_html(url)
        except ValueError as err:
            mill_lst.append((millionaire, None))
            counter += 1
            print(counter, millionaire, err)
            continue

        # Accessing each's millionaire wikipedia page and turning first table into a list.
        wiki = pd.read_html(url)
        wikilist = wiki[0].values.tolist()

        # Data enhancing mode: COUNTRY.
        if enh_mode == "c":

            c = country_or_nationality(con, "c")
            cn = country_or_nationality(con, "b")

            # Looping each "tag" in table/list.
            for x in wikilist:

                # Getting country of origin in "Born" tag.
                if x[0] == "Born":
                    pattern_country = r"\bSouth\s[A-Za-z]+|New\s[A-Za-z]+|[A-Za-z]\.[A-Za-z]\.|[A-Za-z]+\b"
                    born_country = re.findall(pattern_country, x[1])
                    country_found = country_search(born_country, c)
                    if country_found is not None:
                        mill_lst.append((millionaire, country_found))
                        break

                # Getting country of origin in "Nationality" tag if it was not found in previous tag.
                elif x[0] == "Nationality":
                    nationality_found = nationality_country(x[1], cn)
                    if nationality_found is not None:
                        mill_lst.append((millionaire, nationality_found))
                        break

            # Setting country to None if it was not found.
            else:
                mill_lst.append((millionaire, None))

            counter += 1
            print(counter, millionaire, millionaires.index(millionaire), "    ",
                  mill_lst.index(mill_lst[len(mill_lst) - 1]), mill_lst[len(mill_lst) - 1])

        # Data enhancing mode: AGE
        elif enh_mode == "a":

            # Looping each "tag" in table/list.
            for x in wikilist:

                # Getting year of birth in "Born" tag.
                if x[0] == "Born":
                    # Looking for "age xx" string
                    pattern_age = r"age\s\d\d"
                    born_age = re.findall(pattern_age, x[1])
                    if len(born_age) == 1:
                        age_found = int(born_age[0][len(born_age[0]) - 2:len(born_age[0])])
                        mill_lst.append((millionaire, age_found))
                        break

                    # Looking for the year and computing current age
                    pattern_age = r"19\d\d"
                    born_age = re.findall(pattern_age, x[1])
                    age_found = get_age(born_age)
                    if age_found is not None:
                        mill_lst.append((millionaire, age_found))
                        break

            # Setting age to None if it was not found.
            else:
                mill_lst.append((millionaire, None))

            counter += 1
            print(counter, millionaire, millionaires.index(millionaire), "    ",
                  mill_lst.index(mill_lst[len(mill_lst) - 1]), mill_lst[len(mill_lst) - 1])

    if enh_mode == "c":
        enhanced_df = pd.DataFrame(mill_lst, columns=["SearchName", "Nationality"])
        file_name = "enhanced_nationality_df.csv"
        enhanced_df.to_csv(f"../data/processed/{file_name}", index=False)
        print(f"{file_name} was successfully saved!")
        return enhanced_df
    elif enh_mode == "a":
        enhanced_df = pd.DataFrame(mill_lst, columns=["SearchName", "Age"])
        file_name = "enhanced_age_df.csv"
        enhanced_df.to_csv(f"../data/processed/{file_name}", index=False)
        print(f"{file_name} was successfully saved!")
        return enhanced_df

# %%
paises = pd.read_csv("../data/processed/CountryNationality.csv")
clean_df = pd.read_csv("../data/processed/dataclean_info.csv")
test = ['Bernard_Arnault', 'Amancio_Ortega', 'Alice_Walton', 'Jack_Ma', 'Steve_Ballmer', "Elon_Musk"]
mike = ["Michael_Bloomberg"]
bill = ["Bill_Gates"]
chen = ["Charles_S._Cohen"]

# %%
all_names = null_values(clean_df, "g", tolist=True)
#result = data_enhancement(test, "c", paises)

# %%
all_names
# Out:
# ['Bernard_Arnault',
#  'Amancio_Ortega',
#  'Alice_Walton',
#  'Jack_Ma',
#  'Steve_Ballmer',
#  'Wang_Jianlin',
#  'Beate_Heister_&_Karl_Albrecht_Jr.',
#  'David_Thomson',
#  'John_Mars',
#  'Giovanni_Ferrero',
#  'Dietrich_Mateschitz',
#  'Leonardo_Del_Vecchio',
#  'Len_Blavatnik',
#  'He_Xiangjian',
#  'Tadashi_Yanai',
#  'Laurene_Powell_Jobs',
#  'Lee_Kun-Hee',
#  'Ray_Dalio',
#  'Gennady_Timchenko',
#  'Vladimir_Potanin',
#  'Lukas_Walton',
#  'Marcel_Herrmann_Telles',
#  'Jim_Kennedy',
#  'Seo_Jung-Jin',
#  'Stefano_Pessina',
#  'Wang_Wenyin',
#  'John_Menard,_Jr.',
#  'Liu_Qiangdong',
#  'Pan_Zhengmin',
#  'Zong_Qinghou',
#  'Gianluigi_&_Rafaela_Aponte',
#  'Yao_Zhenhua',
#  'James_Irving',
#  'Silvio_Berlusconi',
#  'Hui_Wing_Mau',
#  'David_Duffield',
#  'George_Kaiser',
#  'Patrick_Soon-Shiong',
#  'Zhou_Qunfei',
#  'Pauline_Macmillan_Keinath',
#  'Iskander_Makhmudov',
#  'Shahid_Khan',
#  'Wang_Wenxue',
#  'Willi_&_Isolde_Liebherr',
#  'Chan_Laiwa',
#  'Tsai_Eng-Meng',
#  'Oleg_Deripaska',
#  'Brian_Acton',
#  'Wee_Cho_Yaw',
#  'Leon_Black',
#  'Wei_Jianjun',
#  'Francis_Choi',
#  'Suleiman_Kerimov',
#  'Antonia_Johnson',
#  'David_Cheriton',
#  'Teh_Hong_Piow',
#  'Maria_Asuncion_Aramburuzabala',
#  'Wolfgang_Marguerre',
#  'Marijke_Mars',
#  'Pamela_Mars',
#  'Valerie_Mars',
#  'Kwon_Hyuk-Bin',
#  'Tom_&_Judy_Love',
#  'Robert_Rowling',
#  'John_Tu',
#  'James_Dyson',
#  'Richard_Lefrak',
#  'Rinat_Akhmetov',
#  'Milane_Frantz',
#  'Pan_Sutong',
#  'John_Reece',
#  'Zhang_Shiping',
#  'Marie_Besnier_Beauvalot',
#  'Kjeld_Kirk_Kristiansen',
#  'George_Roberts',
#  'Agnete_Kirk_Thinggaard',
#  'Alexander_Abramov',
#  'Marian_Ilitch',
#  'Pyotr_Aven',
#  'Bernard_Marcus',
#  'Pedro_Moreira_Salles',
#  'Denise_Coates',
#  'Joe_Lewis',
#  'Gabriella_Meister',
#  'Walther_Moreira_Salles_Junior',
#  'Pankaj_Patel',
#  'Ajay_Piramal',
#  'Enrique_Razon,_Jr.',
#  'David_Siegel',
#  'Fu_Liquan',
#  'Philip_&_Cristina_Green',
#  'Mikhail_Gutseriev',
#  'Travis_Kalanick',
#  'Robert_Ziff',
#  'Gwendolyn_Sontheim_Meyer',
#  'Majid_Al_Futtaim',
#  'Chris_Larsen',
#  'Liang_Wengen',
#  'Fang_Wei',
#  'Robert_Miller',
#  'Leonard_Stern',
#  'Anthony_Bamford',
#  'Andrew_Forrest',
#  'Micky_Jagtiani',
#  'Akio_Nitori',
#  'Matthias_Reimann-Andersen',
#  'Jeronimo_Arango',
#  'Austen_Cargill,_Ii.',
#  'Sumet_Jiaravanon',
#  'Bobby_Murphy',
#  'Walter_Scott,_Jr.',
#  'Jack_&_Laura_Dangermond',
#  'Fan_Hongwei',
#  'Montri_Jiaravanont',
#  'Michael_Pieper',
#  'Ursula_Bechtolsheimer-Kipp',
#  'Dan_Friedkin',
#  'Michel_Leclercq',
#  'Richard_Schulze',
#  'Zhang_Yiming',
#  'Rick_Caruso',
#  'Tom_Gores',
#  'Masatoshi_Ito',
#  'Stewart_And_Lynda_Resnick',
#  'Christoph_Zeller',
#  'Chen_Dongsheng',
#  'Dominika_&_Sebastian_Kulczyk',
#  'Masahiro_Miki',
#  'Katharina_Otto-Bernstein',
#  'Ira_Rennert',
#  'Nick_Caporella',
#  'Mark_Cuban',
#  'Jaime_Gilinski_Bacal',
#  'S._Curtis_Johnson',
#  'Viatcheslav_Kantor',
#  'Edward_Johnson,_Iv.',
#  'Elizabeth_Johnson',
#  'Friedhelm_Loh',
#  'Kiran_Mazumdar-Shaw',
#  'Sarath_Ratanavadi',
#  'Zhang_Xin',
#  'Carlo_Benetton',
#  'Kuldip_Singh_&_Gurbachan_Singh_Dhingra',
#  'Edwin_Leong',
#  'Kjell_Inge_Rokke',
#  'Clemens_Toennies',
#  'Carlos_Rodriguez-Pastor',
#  'Teddy_Sagi',
#  'Juan-Miguel_Villar_Mir',
#  'Anil_Agarwal',
#  'Chen_Lip_Keong',
#  'Reid_Hoffman',
#  'Kenneth_Langone',
#  'Li_Sze_Lim',
#  'God_Nisanov',
#  'Hans_Peter_Wild',
#  'Yvonne_Bauer',
#  'Andrew_&_Peggy_Cherng',
#  'Jiang_Bin',
#  'Kurt_Krieger',
#  'Daniel_Loeb',
#  'Luo_Jye',
#  'Ronald_Mcaulay',
#  'Hans_Georg_Naeder',
#  'Daniel_Och',
#  'Lynn_Schusterman',
#  'John_Catsimatidis',
#  'Do_Won_&_Jin_Sook_Chang',
#  'Allan_Goldman',
#  'Amy_Goldman_Fowler',
#  'Manuel_Lao_Hernandez',
#  'Ren_Jianhua',
#  'Donald_Trump',
#  'Wang_Jian',
#  'Clifford_Asness',
#  'Ennio_Doris',
#  'Valentin_Gapontsev',
#  'Martin_Haefner',
#  'Lu_Xiangyang',
#  'Robert_Sands',
#  'Robert_Toennies',
#  'Wu_Kaiting',
#  'Gerald_Ford',
#  'Jamshyd_Godrej',
#  'Joseph_Grendys',
#  'Alicia_Koplowitz',
#  'Louis_Le_Duff',
#  'Yusaku_Maezawa',
#  'Hans_Melchers',
#  'Husnu_Ozyegin',
#  'Thomas_Siebel',
#  'Ralph_Sonnenberg',
#  'Radovan_Vitek',
#  'Carlos_Ardila_Lülle',
#  'William_Conway,_Jr.',
#  'Ding_Shijia',
#  'John_Fisher',
#  'Caroline_Hagen_Kjos',
#  'H._Wayne_Huizenga',
#  'Philip_Niarchos',
#  'Sebastian_Piñera',
#  'Penny_Pritzker',
#  'Nicolas_Puech',
#  'Shi_Yuzhu',
#  'Mark_Walter',
#  'Mohed_Altrad',
#  'Don_Hankey',
#  'Huang_Wei',
#  'Mustafa_Kucuk',
#  'Najib_Mikati',
#  'Bob_Parsons',
#  'Helena_Revoredo',
#  'Phillip_Ruffin',
#  'Tsai_Cheng-Da',
#  'Frank_Vandersloot',
#  'Sandro_Veronesi',
#  'Juan_Abello',
#  'Bang_Jun-Hyuk',
#  'Francesco_Gaetano_Caltagirone',
#  'Chung_Eui-Sun',
#  'Isabel_Dos_Santos',
#  'Phillip_Frost',
#  'Lutz_Mario_Helmig',
#  'Daniel_Mate',
#  'Song_Zuowen',
#  'Glen_Taylor',
#  'Torbjorn_Tornqvist',
#  'Bulat_Utemuratov',
#  'Edward_Bass',
#  'Lee_Bass',
#  'John_Coates',
#  'Jane_Lauder',
#  'Maritsa_Lazari',
#  'Bernard_Lewis',
#  'Aristotelis_Mistakidis',
#  'Yoshiko_Mori',
#  'Adam_Neumann',
#  'P.V._Ramprasad_Reddy',
#  'Larry_Robbins',
#  'Klaus-Peter_Schulenberg',
#  'Charles_Simonyi',
#  'Mark_Stevens',
#  'Elaine_Wynn',
#  'John_Arrillaga',
#  'Vivien_Chen',
#  'Chu_Lam_Yiu',
#  'Andre_Esteves',
#  'Alfred_Gantner',
#  'Hermann_Langness',
#  'Alexander_Mamut',
#  'Sunny_Varkey',
#  'Yu_Minhong',
#  'Chen_Hua',
#  'Dermot_Desmond',
#  'Bernard_Fraisse',
#  'David_Gottesman',
#  'W._Herbert_Hunt',
#  'Lee_Joong-Keun',
#  'Lin_Li',
#  'Clayton_Mathile',
#  'J._Joe_Ricketts',
#  'Tang_Yiu',
#  'Wong_Man_Li',
#  'Lia_Maria_Aguiar',
#  'Chan_Tan_Ching-Fen',
#  'Alexander_Frolov',
#  'He_Qiaonv',
#  'Kong_Jian_Min',
#  'Thomas_Lee',
#  'Eric_Lefkofsky',
#  'Peter_Lim',
#  'Oleg_Tinkov',
#  'William_Young',
#  'Leslie_Alexander',
#  'Patokh_Chodiev',
#  'Choo_Chong_Ngen',
#  'John_De_Mol',
#  'Sanjiv_Goenka',
#  'William_Heinecke',
#  'Huang_Zhenda',
#  'Ravi_Jaipuria',
#  'Kuok_Khoon_Hong',
#  'Christian_Latouche',
#  'Guenther_Lehmann',
#  'Li_Hongxin',
#  'Catherine_Lozick',
#  'Igor_Makarov',
#  'Harsh_Mariwala',
#  'Georg_Nemetschek',
#  'Vikas_Oberoi',
#  'Ong_Beng_Seng_And_Christina_Ong',
#  'Tor_Peterson',
#  'Alexey_Repik',
#  'Shin_Chang-Jae',
#  'Kavitark_Ram_Shriram',
#  'Sylvia_Stroeher',
#  'David_Walentas',
#  'Zhu_Gongshan',
#  'Bernhard_Braun-Luedicke',
#  'Friederike_Braun-Luedicke',
#  'Vivek_Chand_Burman',
#  'Chen_Yung-Tai',
#  'Alexandra_Daitch',
#  'Hu_Kaijun',
#  'Ramesh_Juneja',
#  'Bruce_Karsh',
#  'Harald_Link',
#  'Sarah_Macmillan',
#  'Howard_Marks',
#  'Vadim_Moshkovich',
#  'Chuchat_&_Daonapa_Petaumpai',
#  'Brian_Sheth',
#  'Satoshi_Suzuki',
#  'Katherine_Tanner',
#  'Arvind_Tiku',
#  'Wang_Xicheng',
#  'Jon_Yarbrough',
#  'Kiat_Chiaravanont',
#  'Jean-Paul_And_Martine_Clozel',
#  'Friedrich_Knapp',
#  'Alexander_Nesis',
#  'Jennifer_Pritzker',
#  'Qiu_Jianping',
#  'Megdet_Rahimkulov',
#  'Vito_Rodriguez_Rodriguez',
#  'Stephen_Rubin',
#  'Erik_Selin',
#  'Alan_N._Trefler',
#  'Wang_Qingtao',
#  'Zhang_Daocai',
#  'Zhang_Xuansong',
#  'Alex_Beard',
#  'Nicolas_Berggruen',
#  'Anna_Maria_Braun',
#  'Johanna_Braun',
#  'Karl_Friedrich_Braun',
#  'Anand_Burman',
#  'Cheung_Yan',
#  'Jack_Cowin',
#  'Huang_Qisen',
#  'Masahiro_Noda',
#  'Matthias_Reinhart',
#  'Thaksin_Shinawatra',
#  'William_Stone',
#  'Julia_Stoschek',
#  'Wong_Luen_Hei',
#  'Xu_Hang',
#  'Yang_Erzhu',
#  'Yao_Kuizhang',
#  'Sheng_Jian_Zhong',
#  'Marcel_Adams',
#  'Herbert_Allen,_Jr.',
#  'Emilio_Azcarraga_Jean',
#  'Paolo_Bulgari',
#  'Tony_Chen',
#  'Mehmet_Nazif_Gunal',
#  'Yusuf_Hamied',
#  'Jiang_Yintai',
#  'Kim_Jun-Ki',
#  'Regine_Leibinger',
#  'Lim_Oon_Kuin',
#  'Ma_Xiuhui',
#  'Vincent_Mcmahon',
#  'Massimo_Moratti',
#  'Jerry_Moyes',
#  'Ou_Zongrong',
#  'Pan_Weiming',
#  'Juan_Maria_Riberas_Mera',
#  'Roman_Trotsenko',
#  'Melih_Abdulhayoglu',
#  'Achal_Bakeri',
#  'Othman_Benjelloun',
#  'O._Francis_Biondi',
#  'Cai_Wensheng',
#  'Alexander_Dzhaparidze',
#  'Paul_Foster',
#  'Michael_Jordan',
#  'Pier_Luigi_Loro_Piana',
#  'Billy_Joe_(Red)_Mccombs',
#  'Robert_Mouawad',
#  'Karl-Johan_Persson',
#  'Sheryl_Sandberg',
#  'Charlotte_Soderstrom',
#  'Wang_Yaohai',
#  'Charlotte_Colket_Weber',
#  'Richard_White',
#  'Ted_Alfond',
#  'Joy_Alukkas',
#  'Andrey_Andreev',
#  'Ana_Maria_Brescia_Cafferata',
#  'Mohammed_Dewji',
#  'Asok_Kumar_Hiranandani',
#  'Huang_Qiaoling',
#  'Huang_Zhuangmian',
#  'Li_Weiwei',
#  'William_Li',
#  'Thomas_Meyer',
#  'Ezra_Nahmad',
#  'Jose_Isaac_Peres',
#  'Eddy_Kusnadi_Sariaatmadja',
#  'Monika_Schoeller',
#  'Shamsheer_Vayalil',
#  'Thongma_Vijitpongpun',
#  'Wang_Jiufang',
#  'Zhang_Hongwei',
#  'Zhang_Tao',
#  'Farkhad_Akhmedov',
#  'Bassam_Alghanim',
#  'Alexandra_Andresen',
#  'Nigel_Austin',
#  'Krishna_Kumar_Bangur',
#  'Chey_Ki-Won',
#  'Ciputra',
#  'Victor_Fung',
#  'William_Fung',
#  'Polys_Haji-Ioannou',
#  'Eugene_Kaspersky',
#  'Yuri_Kovalchuk',
#  'James_Leininger',
#  'Anatoly_Lomakin',
#  'Oei_Hong_Leong',
#  'Victor_Pinchuk',
#  'Forrest_Preston',
#  'Evgeny_(Eugene)_Shvidler',
#  'Peter_Sperling',
#  'Jerzy_Starak',
#  'Fuat_Tosyali',
#  'Wang_Qunbin',
#  'Dan_Wilks',
#  'Gavril_Yushvaev',
#  'Zhang_Yubai',
#  'Edmund_Ansin',
#  'Leonid_Boguslavsky',
#  'Steve_Case',
#  'Bruce_Cheng',
#  'Brunello_Cucinelli',
#  'Charles_Dunstone',
#  'Don_Gao',
#  'Ronnen_Harary',
#  'Fahd_Hariri',
#  'Koo_Bon-Neung',
#  'Lin_Fanlian',
#  'Lin_Jianhua',
#  'Jose_Llado_Fernandez-Urrutia',
#  'Cargill_Macmillan,_Iii.',
#  'Craig_Newmark',
#  'Bruce_Nordstrom',
#  'Andreas_Pohl',
#  'Alexander_Rovt',
#  'Lily_Safra',
#  'Karin_Schick',
#  'Eric_Ya_Shen',
#  'Shum_Chiu_Hung',
#  'Sun_Qinghuan',
#  'Sun_Yinhuan',
#  'Djoko_Susanto',
#  'Wang_Muqing',
#  'Hope_Welker',
#  'Wen_Yibo',
#  'Xu_Ziquan',
#  'Yang_Tingdong',
#  'Yu_Peidi',
#  'Zhang_Guiping',
#  'Hamad_Bin_Jassim_Bin_Jaber_Al_Thani',
#  'Eduardo_Belmont_Anderson',
#  'Henadiy_Boholyubov',
#  'Chu_Jinfu',
#  'Eduardo_Costantini',
#  'Sol_Daurella',
#  'Henry_Engelhardt',
#  'Fang_Hongbo',
#  'Donald_Foss',
#  'Robert_Friedland',
#  'Dan_Gertler',
#  'Gudrun_Heine',
#  'Francis_Holder',
#  'B._Wayne_Hughes,_Jr.',
#  'Jiang_Ganjun',
#  'Jin_Huiming',
#  'Lee_Hae-Jin',
#  'Liu_Zhenguo',
#  'Tobi_Lutke',
#  "Ana_Maria_Marcondes_Penido_Sant'Anna",
#  'Andrei_Molchanov',
#  'Kentaro_Ogawa',
#  'Ron_Sim',
#  'Yoshikazu_Tanaka',
#  'Tian_Ming',
#  'Mustafa_Latif_Topbas',
#  'Wang_Wenbiao',
#  'Xu_Xiong',
#  'Yan_Yude',
#  'William_Ackman',
#  'Emanuella_Barilla',
#  'J._Hyatt_Brown',
#  'Bu_Yang',
#  'Chen_Shiliang',
#  'Chen_Xiaxin',
#  'Joseph_Edelman',
#  'Wolfgang_Egger',
#  'Andrei_Filatov',
#  'Paul_Fireman',
#  'Bent_Jensen',
#  'Koo_Bon-Joon',
#  'Randolph_Lerner',
#  'Li_Weiguo',
#  'Liang_Guangwei',
#  'Liang_Shezeng',
#  'Liao_Chang',
#  'Jenny_Lindén_Urnes',
#  'Nikita_Mishin',
#  "Michael_O'Leary",
#  'Roberto_Ongpin',
#  'Peng_Jianhu',
#  'Marc_Samwer',
#  'Michael_Steinhardt',
#  'James_Truchard',
#  'Wang_Miaotong',
#  'Wang_Zhenghua',
#  'Zhou_Zongwen',
#  'Chen_Jianming',
#  'Cho_Yang-Rai',
#  'Yvon_Chouinard',
#  'John_Collison',
#  'Henry_Davis',
#  'Francois_Feuillet',
#  'Yuri_Gushchin',
#  'Huang_Xiaofen',
#  'Tarang_Jain',
#  'Jiang_Xuefei',
#  'Morris_Kahn',
#  'Anton_Kathrein,_Jr.',
#  'Michael_Kim',
#  'Koo_Bon-Sik',
#  'Igor_Kudryashkin',
#  'John_Liew',
#  'Paul_Little',
#  'Lu_Weiding',
#  'Duncan_Macmillan',
#  'Sergei_Petrov',
#  'Alice_Schwartz',
#  'Martin_Selig',
#  'Sathien_Setthasit',
#  'Evan_Sharp',
#  'Ravindra_Kishore_Sinha',
#  'Axel_Stawski',
#  'V._Prem_Watsa',
#  'Yao_Xinyi',
#  'Zhu_Xingming',
#  'Olgun_Zorlu']

# %%
clean_df.head()
# Out:
#      id             name   age gender        country  \
# 0  7468       Jeff Bezos  54.0   Male  United States
# 1  4605       Bill Gates  62.0   Male            NaN
# 2  7368   Warren Buffett  87.0   Male            NaN
# 3  3808  Bernard Arnault  69.0    NaN            NaN
# 4  3213  Mark Zuckerberg  33.0   Male            NaN
#
#                                                image                   Sector  \
# 0  https://specials-images.forbesimg.com/imageser...               Technology
# 1  https://specials-images.forbesimg.com/imageser...               Technology
# 2  https://specials-images.forbesimg.com/imageser...  Finance and Investments
# 3  https://specials-images.forbesimg.com/imageser...         Fashion & Retail
# 4  https://specials-images.forbesimg.com/imageser...               Technology
#
#               Company  Worth(BUSD)       SearchName
# 0              Amazon        112.0       Jeff_Bezos
# 1           Microsoft         90.0       Bill_Gates
# 2  Berkshire Hathaway         84.0   Warren_Buffett
# 3                LVMH         72.0  Bernard_Arnault
# 4            Facebook         71.0  Mark_Zuckerberg

# %%
def merge_enhanced_data(original_df, toadd_df, column_to_improve, column_to_drop):
    original_df["SearchName"] = original_df["name"].apply(lambda full_name: "_".join(full_name.strip().split()))
    enhanced_df = pd.merge(original_df, toadd_df, how="left", on="SearchName")
    enhanced_df.drop(columns=["SearchName", column_to_improve], axis=1, inplace=True)
    enhanced_df.rename(columns={column_to_drop : column_to_improve}, inplace=True)
    enhanced_df = enhanced_df[['id', 'name', 'age', 'gender', 'country', 'image', 'Sector', 'Company', 'Worth(BUSD)']]
    return enhanced_df

# %%
merge_enhanced_data(clean_df, result, "age", "Age")
# Out:
#         id             name   age  gender        country  \
# 0     7468       Jeff Bezos   NaN    Male  United States
# 1     4605       Bill Gates   NaN    Male            NaN
# 2     7368   Warren Buffett   NaN    Male            NaN
# 3     3808  Bernard Arnault  70.0     NaN            NaN
# 4     3213  Mark Zuckerberg   NaN    Male            NaN
# ...    ...              ...   ...     ...            ...
# 2203  7578   Zhao Xiaoqiang   NaN    Male          China
# 2204  9196  Zhou Liangzhang   NaN    Male            NaN
# 2205  1175     Zhu Xingming   NaN     NaN          China
# 2206  9466         Zhuo Jun   NaN  Female            NaN
# 2207  2718      Olgun Zorlu   NaN     NaN            NaN
#
#                                                   image  \
# 0     https://specials-images.forbesimg.com/imageser...
# 1     https://specials-images.forbesimg.com/imageser...
# 2     https://specials-images.forbesimg.com/imageser...
# 3     https://specials-images.forbesimg.com/imageser...
# 4     https://specials-images.forbesimg.com/imageser...
# ...                                                 ...
# 2203  https://specials-images.forbesimg.com/imageser...
# 2204  https://specials-images.forbesimg.com/imageser...
# 2205  https://specials-images.forbesimg.com/imageser...
# 2206  https://specials-images.forbesimg.com/imageser...
# 2207  https://specials-images.forbesimg.com/imageser...
#
#                        Sector                 Company  Worth(BUSD)
# 0                  Technology                  Amazon        112.0
# 1                  Technology               Microsoft         90.0
# 2     Finance and Investments      Berkshire Hathaway         84.0
# 3            Fashion & Retail                    LVMH         72.0
# 4                  Technology                Facebook         71.0
# ...                       ...                     ...          ...
# 2203         Fashion & Retail  fashion, entertainment          1.0
# 2204            Manufacturing    electrical equipment          1.0
# 2205            Manufacturing    electrical equipment          1.0
# 2206            Manufacturing  printed circuit boards          1.0
# 2207              Diversified             diversified          1.0
#
# [2208 rows x 9 columns]
